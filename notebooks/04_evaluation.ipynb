# %% [markdown]
# # Stage 4: Evaluation & Visualization
# Nhiệm vụ: Đánh giá độ chính xác của mô hình và vẽ biểu đồ trực quan.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# TODO: Load model, predict and plot results
