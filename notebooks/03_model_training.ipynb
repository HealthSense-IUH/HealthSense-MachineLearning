# %% [markdown]
# # Stage 3: Model Training (Random Forest)
# Nhiệm vụ: Dạy cho AI cách nhận biết trạng thái sức khỏe dựa trên các Feature đã trích xuất.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import joblib

# TODO: Train model
